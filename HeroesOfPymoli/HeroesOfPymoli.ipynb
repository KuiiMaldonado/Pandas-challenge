# %%
#Import modules
import pandas as pd
import os

# %%
#Csv file path
filePath = os.path.join("Resources", "purchase_data.csv")

# %%
#Read file and create data frame
pymoli_heroes_df = pd.read_csv(filePath)
pymoli_heroes_df.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %%
#Get total number of players
total_players = len(pymoli_heroes_df["SN"].unique())
total_players
# Out:
# 576

# %%
#Number of unique items
total_items = len(pymoli_heroes_df["Item Name"].unique())

#Average purchase price
mean_purchase = pymoli_heroes_df["Price"].mean()
mean_purchase = float("{0:.2f}".format(mean_purchase))

#Total purchases
total_purchases = len(pymoli_heroes_df.index)

#Total Revenue
total_revenue = pymoli_heroes_df["Price"].sum()

#Showing data in a Data Frame
purchasing_analysis_df = pd.DataFrame({"Total Unique Items":[total_items], "Average Price":[mean_purchase],
                                       "Total Purchases":[total_purchases], "Total Revenue":[total_revenue]})
purchasing_analysis_df
# Out:
#    Total Unique Items  Average Price  Total Purchases  Total Revenue
# 0                 179           3.05              780        2379.77

# %%
#Percentage and number of male players
male_players = pymoli_heroes_df.loc[pymoli_heroes_df["Gender"] == "Male"]
total_male_players = len(male_players["SN"].unique())
prct_male_players = (total_male_players / total_players)
prct_male_players = "{:.2%}".format(prct_male_players)

#Percentage and number of female players
female_players = pymoli_heroes_df.loc[pymoli_heroes_df["Gender"] == "Female"]
total_female_players = len(female_players["SN"].unique())
prct_female_players = (total_female_players / total_players)
prct_female_players = "{:.2%}".format(prct_female_players)

#Percentage and number of "other" gender players
other_players = pymoli_heroes_df.loc[pymoli_heroes_df["Gender"] == "Other / Non-Disclosed"]
total_other_players = len(other_players["SN"].unique())
prct_other_players = (total_other_players / total_players)
prct_other_players = "{:.2%}".format(prct_other_players)

#Showing Gender Demographics
gender_analysis_df = pd.DataFrame({"Gender":["Male", "Female", "Other / Non-Disclosed"],
                                  "Total Count":[total_male_players, total_female_players, total_other_players],
                                  "Percentage of Players":[prct_male_players, prct_female_players, prct_other_players]})
gender_analysis_df.set_index("Gender")
# Out:
#                        Total Count Percentage of Players
# Gender
# Male                           484                84.03%
# Female                          81                14.06%
# Other / Non-Disclosed           11                 1.91%

# %%
#Male gender analysis
#Total purchases
total_male_purchases = len(male_players)

#Average purchase price
male_mean_purchase = male_players["Price"].mean()

#Total purchase
male_total_revenue = male_players["Price"].sum()

#Average purchase per person(male)
male_mean_person = male_total_revenue / total_male_players

#Female gender analysis
#Total purchases
total_female_purchases = len(female_players)

#Average purchase price
female_mean_purchase = female_players["Price"].mean()

#Total purchase
female_total_revenue = female_players["Price"].sum()

#Average purchase per person(female)
female_mean_person = female_total_revenue / total_female_players

#Other gender analysis
#Total purchases
total_other_purchases = len(other_players)

#Average purchase price
other_mean_purchase = other_players["Price"].mean()

#Total purchase
other_total_revenue = other_players["Price"].sum()

#Average purchase per person(other)
other_mean_person = other_total_revenue / total_other_players

genderPurchase_analysis_df = pd.DataFrame({"Gender":["Male", "Female", "Other / Non-Disclosed"],
                                          "Purchase Count": [total_male_purchases, total_female_purchases, total_other_purchases],
                                          "Average Purchase Price":[male_mean_purchase, female_mean_purchase, other_mean_purchase],
                                          "Total Purchase Value":[male_total_revenue, female_total_revenue, male_total_revenue],
                                          "Avg Total Purchase per Person":[male_mean_person, female_mean_person, other_mean_person]})

genderPurchase_analysis_df["Average Purchase Price"] = genderPurchase_analysis_df["Average Purchase Price"].map("${:.2f}".format)
genderPurchase_analysis_df["Total Purchase Value"] = genderPurchase_analysis_df["Total Purchase Value"].map("${:.2f}".format)
genderPurchase_analysis_df["Avg Total Purchase per Person"] = genderPurchase_analysis_df["Avg Total Purchase per Person"].map("${:.2f}".format)
genderPurchase_analysis_df.set_index("Gender")
# Out:
#                        Purchase Count Average Purchase Price  \
# Gender
# Male                              652                  $3.02
# Female                            113                  $3.20
# Other / Non-Disclosed              15                  $3.35
#
#                       Total Purchase Value Avg Total Purchase per Person
# Gender
# Male                              $1967.64                         $4.07
# Female                             $361.94                         $4.47
# Other / Non-Disclosed             $1967.64                         $4.56

# %%
#Age demographics
bins = [0, 9, 14, 19, 24, 29, 34, 39, 45]
group_labels = ["<10", "10-14", "15-19", "20-24", "25-29", "30-34", "35-39", "40+"]

#Data frame for age analysis only
age_df = pd.DataFrame(pymoli_heroes_df.drop_duplicates("SN"))

age_df["Age Ranges"] = pd.DataFrame(pd.cut(pymoli_heroes_df["Age"], bins, labels=group_labels))

age_list = []
for label in group_labels:
    age_list.append(len(age_df.loc[age_df["Age Ranges"] == label]))

prct_age_list = []
for x in age_list:
    prct_age_list.append((x / total_players) * 100)

age_dem_df = pd.DataFrame({"Age Ranges":group_labels, "Total Count":age_list, "Percentage of Players":prct_age_list})
age_dem_df["Percentage of Players"] = age_dem_df["Percentage of Players"].map("{:.2f}%".format)
age_dem_df.set_index("Age Ranges")
# Out:
#             Total Count Percentage of Players
# Age Ranges
# <10                  17                 2.95%
# 10-14                22                 3.82%
# 15-19               107                18.58%
# 20-24               258                44.79%
# 25-29                77                13.37%
# 30-34                52                 9.03%
# 35-39                31                 5.38%
# 40+                  12                 2.08%

# %%
#Age purchase analysis
age_purchase_df = pd.DataFrame(pymoli_heroes_df)
age_purchase_df["Age Ranges"] = pd.DataFrame(pd.cut(pymoli_heroes_df["Age"], bins, labels=group_labels))

total_list = []
avg_list = []
purchase_list = []
avgPerson_list = []

for label in group_labels:
    total_list.append(len(age_purchase_df.loc[age_purchase_df["Age Ranges"] == label]["Price"]))
    avg_list.append(age_purchase_df.loc[age_purchase_df["Age Ranges"] == label]["Price"].mean())
    purchase_list.append(age_purchase_df.loc[age_purchase_df["Age Ranges"] == label]["Price"].sum())
    
for x in range(0, len(total_list)):
    avgPerson_list.append((purchase_list[x] / age_list[x]))
    
age_purchase_df = pd.DataFrame({"Age Ranges":group_labels, "Purchase Count":total_list, "Average Purchase Price":avg_list,
                               "Total Purchase Value":purchase_list, "Avg Total Purchase per Person": avgPerson_list})
age_purchase_df["Average Purchase Price"] = age_purchase_df["Average Purchase Price"].map("${:.2f}".format)
age_purchase_df["Total Purchase Value"] = age_purchase_df["Total Purchase Value"].map("${:.2f}".format)
age_purchase_df["Avg Total Purchase per Person"] = age_purchase_df["Avg Total Purchase per Person"].map("${:.2f}".format)
age_purchase_df.set_index("Age Ranges")
# Out:
#             Purchase Count Average Purchase Price Total Purchase Value  \
# Age Ranges
# <10                     23                  $3.35               $77.13
# 10-14                   28                  $2.96               $82.78
# 15-19                  136                  $3.04              $412.89
# 20-24                  365                  $3.05             $1114.06
# 25-29                  101                  $2.90              $293.00
# 30-34                   73                  $2.93              $214.00
# 35-39                   41                  $3.60              $147.67
# 40+                     13                  $2.94               $38.24
#
#            Avg Total Purchase per Person
# Age Ranges
# <10                                $4.54
# 10-14                              $3.76
# 15-19                              $3.86
# 20-24                              $4.32
# 25-29                              $3.81
# 30-34                              $4.12
# ...

# %%
#Top 5 spenders
players_array = pymoli_heroes_df["SN"].unique()
spent_list = []
purchase_count = []
avg_top = []

for player in players_array:
    count = len(pymoli_heroes_df.loc[pymoli_heroes_df["SN"] == player])
    purchase_count.append(count)
    amount = pymoli_heroes_df.loc[pymoli_heroes_df["SN"] == player]["Price"].sum()
    spent_list.append(amount)
    avg_top.append(amount / count)

top_spenders_df = pd.DataFrame({"SN":players_array, "Purchase Count":purchase_count, "Average Purchase Price":avg_top,
                               "Total Purchase Value":spent_list})

top_spenders_df = top_spenders_df.sort_values(by=["Total Purchase Value"], ascending=False)
top_spenders_df["Average Purchase Price"] = top_spenders_df["Average Purchase Price"].map("${:.2f}".format)
top_spenders_df["Total Purchase Value"] = top_spenders_df["Total Purchase Value"].map("${:.2f}".format)
top_spenders_df.set_index("SN").head()
# Out:
#              Purchase Count Average Purchase Price Total Purchase Value
# SN
# Lisosia93                 5                  $3.79               $18.96
# Idastidru52               4                  $3.86               $15.45
# Chamjask73                3                  $4.61               $13.83
# Iral74                    4                  $3.40               $13.62
# Iskadarya95               3                  $4.37               $13.10

# %%
#Most popular items
items_df = pd.DataFrame(pymoli_heroes_df.sort_values(by=["Item ID"]))

item_id_array = items_df["Item ID"].unique()

purchase_item_count = []
item_total_price = []
item_price = []
for item in item_id_array:
    counter = len(items_df.loc[items_df["Item ID"] == item])
    purchase_item_count.append(counter)
    total = items_df.loc[items_df["Item ID"] == item]["Price"].sum()
    item_total_price.append(total)
    item_price.append(total / counter)

item_analysis_df = pd.DataFrame(items_df.drop_duplicates("Item ID"))
items_array = item_analysis_df["Item Name"]

    
items_analysis_df = pd.DataFrame({"Item ID":item_id_array, "Item Name":items_array, "Purchase Count":purchase_item_count, "Item Price":item_price,
                        "Total Purchase Value":item_total_price})

popular_items_df = items_analysis_df.sort_values(by=["Purchase Count"], ascending=False)
popular_items_df["Item Price"] = popular_items_df["Item Price"].map("${:.2f}".format)
popular_items_df["Total Purchase Value"] = popular_items_df["Total Purchase Value"].map("${:.2f}".format)
popular_items_df.set_index(["Item ID", "Item Name"]).head()
# Out:
#                                                       Purchase Count  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm              12
# 145     Fiery Glass Crusader                                       9
# 108     Extraction, Quickblade Of Trembling Hands                  9
# 82      Nirvana                                                    9
# 19      Pursuit, Cudgel of Necromancy                              8
#
#                                                      Item Price  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm      $4.23
# 145     Fiery Glass Crusader                              $4.58
# 108     Extraction, Quickblade Of Trembling Hands         $3.53
# 82      Nirvana                                           $4.90
# 19      Pursuit, Cudgel of Necromancy                     $1.02
#
#                                                      Total Purchase Value
# Item ID Item Name
# ...

# %%
#Most profitable items
profitable_items = pd.DataFrame(items_analysis_df)
profitable_items = profitable_items.sort_values(by=["Total Purchase Value"], ascending=False)
profitable_items["Item Price"] = profitable_items["Item Price"].map("${:.2f}".format)
profitable_items["Total Purchase Value"] = profitable_items["Total Purchase Value"].map("${:.2f}".format)
profitable_items.set_index(["Item ID", "Item Name"]).head()
# Out:
#                                                       Purchase Count  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm              12
# 82      Nirvana                                                    9
# 145     Fiery Glass Crusader                                       9
# 92      Final Critic                                               8
# 103     Singed Scalpel                                             8
#
#                                                      Item Price  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm      $4.23
# 82      Nirvana                                           $4.90
# 145     Fiery Glass Crusader                              $4.58
# 92      Final Critic                                      $4.88
# 103     Singed Scalpel                                    $4.35
#
#                                                      Total Purchase Value
# Item ID Item Name
# ...
